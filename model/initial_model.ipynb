# %% [markdown]
# # Initial Model
#
# Using detectron2 the hope for this model is to be able to predict to a somewhat accurate degree math symbols from a handwritten image. Detectron2 is a object detection framework created by facebook which provides abstractions to models like RCNN that specialize in object detection. Read more about it here https://github.com/facebookresearch/detectron2.
#
# ## The Dataset
#
# To achieve this the Aida Calculus Math Handwriting Recognition Dataset was used (https://www.kaggle.com/datasets/aidapearson/ocr-data). This is a dataset created with the goal of training a math recognition model based off of difficult to interpret math equations. Especially equations that include a fraction. Each batch of images provided has an associated JSON file. This JSON file provides information about the image, the "bounding box" for each symbol in the image, and the label for each symbol. Each label is provided with the cooresponding latex character.
#
# There is around 100,000 images and annotations in this dataset. But in this notebook only one batch (10,000) images are going to be used for training.

# %%
# Some basic setup:
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import os, cv2, json, random
from pathlib import Path

# import some common detectron2 utilities
from detectron2 import model_zoo
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog, DatasetCatalog
from detectron2.structures import BoxMode

# %% [markdown]
# ## Formatting the Dataset
#
# Per detectron2 requirements, the dataset must be in provided in a list of dictionaries. The format can be read in more detail in https://detectron2.readthedocs.io/en/latest/tutorials/datasets.html.
#
# An important component in that format is that the labels must be provided via an integer. As mentioned earlier, this dataset provides its label via a latex character. Meaning that we must keep track of all characters and their cooresponding integer value.
#
# This will be stored in a dictionary where the key is the latex character and the value is the corresponding integer.

# %%
# Creating some globally used variables
label_mappings = None # this will store the integer values of each label

path_to_training_batch = "/home/jefferse/batch_1/batch_1/"
    # this is the path to the JSON file of a batch of the Aida Calc data
    
path_to_testing_batch = "/home/jefferse/testing_data/"

json_data_global = {} # dictionary that will store json data based on path so it does not need to be read everytime

# %%
def get_json_data(json_path):
    global json_data_global
    if json_path not in json_data_global:
        with open(json_path) as file:
                json_data_global[json_path] = json.load(file)
    return json_data_global[json_path]

# %%
def get_label_mapping(json_path=path_to_training_batch + "JSON/kaggle_data_1.json"):
    
    global label_mappings
    
    if label_mappings is None: # need to create the mapping
        label_mappings = {}
        key = 0
        
        json_data = get_json_data(json_path)
            
            
        for image in range(len(json_data)): #loop through each image in the JSON file
            label = json_data[image]["image_data"]["visible_latex_chars"]
            for latex_char in label: # now loop through all of the labels in that image
                if latex_char not in label_mappings: 
                    label_mappings[latex_char] = key
                    key = key + 1
                    
    return label_mappings

# %% [markdown]
# ### Format Structure
#
# The data must be in the following structure
#
# ![image.png](attachment:image.png)

# %%
def get_formatted_data(json_path=path_to_training_batch + "JSON/kaggle_data_1.json", batch_path=path_to_training_batch + "background_images/"):
    
    data = []

    json_data = get_json_data(json_path)
    
    id = 0

    for image in range(len(json_data)): # need to format the annotations for each image
        current = json_data[image]["image_data"]
            
        if Path(batch_path + json_data[image]["filename"]).exists(): # make sure the image exists in storage
        
            anns = []
            for i in range(len(current["xmins_raw"])):
              bboxes = [current["xmins_raw"][i], current["ymins_raw"][i], current["xmaxs_raw"][i], current["ymaxs_raw"][i]]

              obj = {
                "bbox" : bboxes,
                "bbox_mode": BoxMode.XYXY_ABS,
                "category_id" : get_label_mapping()[current["visible_latex_chars"][i]]
              }
              anns.append(obj)


            data.append({
                "file_name" : batch_path + json_data[image]["filename"],
                "image_id" : id,
                "width" : current["width"],
                "height" : current["height"],
                "annotations" : anns
            })
            
            id = id + 1


    return data

# %% [markdown]
# ## Registering the Dataset
#
# Now detectron needs to know about the dataset. Most of the work is done since a function has already been made that provides this dataset. But two things need to happen still
#
# 1. Register Dataset
# 2. Register Metadata
#
# The dataset is the values, the bounding box, and everything that was formatted above. Whereas the Metadata is just the labels that these annotations can have. Detectron2 provides tools in order to register these.

# %%
DatasetCatalog.register("calc_training", lambda: get_formatted_data())
MetadataCatalog.get("calc_training").thing_classes = list(get_label_mapping().keys())

DatasetCatalog.register("calc_testing", lambda: get_formatted_data(batch_path=path_to_testing_batch + "background_images/", json_path=path_to_testing_batch+"JSON/kaggle_data_2.json"))
MetadataCatalog.get("calc_testing").thing_classes = list(get_label_mapping().keys())

# %% [markdown]
# Let's see if importing the data really worked now.....

# %%
from detectron2.utils.visualizer import ColorMode
import matplotlib.pyplot as plt 

data = get_formatted_data()

for image in random.sample(data, 3):
    img = cv2.imread(image["file_name"])
    v = Visualizer(img[:, :, ::-1],
                   metadata=MetadataCatalog.get("calc_training"),
                   scale=0.5,
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels. This option is only available for segmentation models
    )
    out = v.draw_dataset_dict(image)
    plt.imshow(out.get_image()[:, :, ::-1], cmap = 'gray', interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.show()

# %% [markdown]
# # Training the Data
#
# This is the most basic configuration there is. Detectron2 offers pretrained models, the one being used in this is a pretrained RCNN. This is just to ensure that the training works at the very least. Optimizations will be made in the next iteration of this.

# %%
from detectron2.engine import DefaultTrainer


cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
cfg.DATASETS.TRAIN = ("calc_training",)
cfg.DATASETS.TEST = ("calc_testing",) 
cfg.TEST.EVAL_PERIOD = 100
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml")  # Let training initialize from model zoo
cfg.SOLVER.IMS_PER_BATCH = 2  
cfg.SOLVER.BASE_LR = 0.00025  
cfg.SOLVER.MAX_ITER = 300    
cfg.SOLVER.STEPS = []        # do not decay learning rate
cfg.MODEL.ROI_HEADS.BATCH_SIZE_PER_IMAGE = 128   
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 54

trainer = DefaultTrainer(cfg) 
trainer.resume_or_load(resume=False)
trainer.train()
# Out:
# [12/03 21:22:44 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=55, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=216, bias=True)
#     )
#   )
# )
# [12/03 21:22:47 d2.data.build]: Removed 0 images with no usable annotations. 10000 images left.
# [12/03 21:22:47 d2.data.build]: Distribution of instances among all 54 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   \lim_    | 11147        |     a      | 1428         |    \to     | 11147        |
# |   \frac    | 14868        |    \pi     | 4506         |     4      | 4332         |
# |     d      | 5932         |   \left(   | 6258         |    \sin    | 3998         |
# |     +      | 11864        |     -      | 9468         |     6      | 4303         |
# |    \sec    | 1141         |  \right)   | 6258         |     w      | 3086         |
# |     /      | 2599         |     5      | 4217         |    \tan    | 3513         |
# |     2      | 9055         |     3      | 6363         |     e      | 699          |
# |     b      | 1596         |     7      | 4192         |    \cos    | 3007         |
# |   \theta   | 1573         |     8      | 4166         |     =      | 1105         |
# |     x      | 6527         |     9      | 4364         |     1      | 3506         |
# |     y      | 2787         |     h      | 3197         |     k      | 1830         |
# |     g      | 1645         |    \csc    | 660          |   \infty   | 2060         |
# |     0      | 1898         |   \sqrt    | 1187         |     r      | 1448         |
# |    \ln     | 1108         |     n      | 1255         |     u      | 3110         |
# |    \cot    | 303          |   \left|   | 467          |  \right|   | 467          |
# |     p      | 1625         |     t      | 2456         |     z      | 1843         |
# |    \log    | 1484         |     v      | 1440         |     s      | 1406         |
# |     c      | 1650         |   \cdot    | 99           |     .      | 6            |
# |            |              |            |              |            |              |
# |   total    | 191649       |            |              |            |              |
# [12/03 21:22:47 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [12/03 21:22:47 d2.data.build]: Using training sampler TrainingSampler
# [12/03 21:22:47 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [12/03 21:22:47 d2.data.common]: Serializing 10000 elements to byte tensors and concatenating them all ...
# [12/03 21:22:47 d2.data.common]: Serialized dataset takes 7.54 MiB
# [12/03 21:22:47 d2.data.build]: Making batched data loader with batch_size=2
# [12/03 21:22:47 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-Detection/faster_rcnn_R_50_FPN_3x/137849458/model_final_280758.pkl ...
# Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (55, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (55,) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (216, 1024) in the model! You might want to double check if this is expected.
# Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (216,) in the model! You might want to double check if this is expected.
# Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# [12/03 21:22:48 d2.engine.train_loop]: Starting training from iteration 0
# /home/jefferse/.conda/envs/local_detectron/lib/python3.10/site-packages/torch/functional.py:504: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3526.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]
# [12/03 21:22:57 d2.utils.events]:  eta: 0:01:29  iter: 19  total_loss: 6.81  loss_cls: 4.004  loss_box_reg: 0.8314  loss_rpn_cls: 1.607  loss_rpn_loc: 0.4029    time: 0.3330  last_time: 0.2732  data_time: 0.0123  last_data_time: 0.0026   lr: 1.6068e-05  max_mem: 2459M
# [12/03 21:23:05 d2.utils.events]:  eta: 0:01:23  iter: 39  total_loss: 5.253  loss_cls: 3.722  loss_box_reg: 0.8655  loss_rpn_cls: 0.1732  loss_rpn_loc: 0.3882    time: 0.3366  last_time: 0.2295  data_time: 0.0043  last_data_time: 0.0029   lr: 3.2718e-05  max_mem: 2548M
# [12/03 21:23:11 d2.utils.events]:  eta: 0:01:15  iter: 59  total_loss: 4.416  loss_cls: 3.046  loss_box_reg: 0.8516  loss_rpn_cls: 0.07863  loss_rpn_loc: 0.3407    time: 0.3244  last_time: 0.2430  data_time: 0.0027  last_data_time: 0.0028   lr: 4.9367e-05  max_mem: 2639M
# [12/03 21:23:17 d2.utils.events]:  eta: 0:01:09  iter: 79  total_loss: 3.119  loss_cls: 1.714  loss_box_reg: 0.8609  loss_rpn_cls: 0.07672  loss_rpn_loc: 0.3565    time: 0.3230  last_time: 0.2790  data_time: 0.0028  last_data_time: 0.0026   lr: 6.6017e-05  max_mem: 2639M
# [12/03 21:23:31 d2.data.build]: Distribution of instances among all 54 categories:
# |  category  | #instances   |  category  | #instances   |  category  | #instances   |
# |:----------:|:-------------|:----------:|:-------------|:----------:|:-------------|
# |   \lim_    | 2781         |     a      | 364          |    \to     | 2781         |
# |   \frac    | 3468         |    \pi     | 970          |     4      | 1120         |
# |     d      | 844          |   \left(   | 1290         |    \sin    | 1061         |
# |     +      | 2922         |     -      | 2384         |     6      | 1059         |
# |    \sec    | 283          |  \right)   | 1290         |     w      | 797          |
# |     /      | 589          |     5      | 1052         |    \tan    | 889          |
# |     2      | 2399         |     3      | 1617         |     e      | 162          |
# |     b      | 312          |     7      | 996          |    \cos    | 748          |
# |   \theta   | 292          |     8      | 1075         |     =      | 248          |
# |     x      | 1628         |     9      | 1083         |     1      | 936          |
# |     y      | 810          |     h      | 856          |     k      | 363          |
# |     g      | 465          |    \csc    | 185          |   \infty   | 583          |
# |     0      | 511          |   \sqrt    | 335          |     r      | 272          |
# |    \ln     | 247          |     n      | 349          |     u      | 772          |
# |    \cot    | 89           |   \left|   | 113          |  \right|   | 113          |
# |     p      | 428          |     t      | 744          |     z      | 400          |
# |    \log    | 440          |     v      | 355          |     s      | 354          |
# |     c      | 386          |   \cdot    | 30           |     .      | 6            |
# |            |              |            |              |            |              |
# |   total    | 46646        |            |              |            |              |
# [12/03 21:23:31 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/03 21:23:31 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [12/03 21:23:31 d2.data.common]: Serializing 2560 elements to byte tensors and concatenating them all ...
# [12/03 21:23:31 d2.data.common]: Serialized dataset takes 1.86 MiB
# WARNING [12/03 21:23:31 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [12/03 21:23:31 d2.utils.events]:  eta: 0:01:02  iter: 99  total_loss: 2.856  loss_cls: 1.508  loss_box_reg: 0.869  loss_rpn_cls: 0.0601  loss_rpn_loc: 0.4264    time: 0.3187  last_time: 0.2266  data_time: 0.0027  last_data_time: 0.0025   lr: 8.2668e-05  max_mem: 2639M
# [12/03 21:23:38 d2.utils.events]:  eta: 0:00:56  iter: 119  total_loss: 2.695  loss_cls: 1.441  loss_box_reg: 0.8558  loss_rpn_cls: 0.05977  loss_rpn_loc: 0.2813    time: 0.3219  last_time: 0.3144  data_time: 0.0027  last_data_time: 0.0029   lr: 9.9318e-05  max_mem: 2640M
# [12/03 21:23:45 d2.utils.events]:  eta: 0:00:50  iter: 139  total_loss: 2.693  loss_cls: 1.409  loss_box_reg: 0.8692  loss_rpn_cls: 0.06247  loss_rpn_loc: 0.3567    time: 0.3233  last_time: 0.2847  data_time: 0.0027  last_data_time: 0.0030   lr: 0.00011597  max_mem: 2640M
# [12/03 21:23:51 d2.utils.events]:  eta: 0:00:43  iter: 159  total_loss: 2.697  loss_cls: 1.394  loss_box_reg: 0.8607  loss_rpn_cls: 0.06281  loss_rpn_loc: 0.3926    time: 0.3207  last_time: 0.4750  data_time: 0.0027  last_data_time: 0.0028   lr: 0.00013262  max_mem: 2640M
# [12/03 21:23:57 d2.utils.events]:  eta: 0:00:37  iter: 179  total_loss: 2.644  loss_cls: 1.371  loss_box_reg: 0.8862  loss_rpn_cls: 0.05322  loss_rpn_loc: 0.3884    time: 0.3194  last_time: 0.3209  data_time: 0.0029  last_data_time: 0.0026   lr: 0.00014927  max_mem: 2640M
# [12/03 21:24:04 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/03 21:24:04 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [12/03 21:24:04 d2.data.common]: Serializing 2560 elements to byte tensors and concatenating them all ...
# [12/03 21:24:04 d2.data.common]: Serialized dataset takes 1.86 MiB
# WARNING [12/03 21:24:04 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.
# [12/03 21:24:04 d2.utils.events]:  eta: 0:00:30  iter: 199  total_loss: 2.553  loss_cls: 1.369  loss_box_reg: 0.8302  loss_rpn_cls: 0.07914  loss_rpn_loc: 0.3059    time: 0.3166  last_time: 0.2363  data_time: 0.0029  last_data_time: 0.0028   lr: 0.00016592  max_mem: 2640M
# [12/03 21:24:11 d2.utils.events]:  eta: 0:00:24  iter: 219  total_loss: 2.61  loss_cls: 1.368  loss_box_reg: 0.8631  loss_rpn_cls: 0.05307  loss_rpn_loc: 0.3175    time: 0.3180  last_time: 0.3216  data_time: 0.0028  last_data_time: 0.0026   lr: 0.00018257  max_mem: 2640M
# [12/03 21:24:17 d2.utils.events]:  eta: 0:00:18  iter: 239  total_loss: 2.549  loss_cls: 1.31  loss_box_reg: 0.8556  loss_rpn_cls: 0.05244  loss_rpn_loc: 0.2699    time: 0.3162  last_time: 0.3264  data_time: 0.0028  last_data_time: 0.0030   lr: 0.00019922  max_mem: 2640M
# [12/03 21:24:23 d2.utils.events]:  eta: 0:00:12  iter: 259  total_loss: 2.574  loss_cls: 1.287  loss_box_reg: 0.8519  loss_rpn_cls: 0.0492  loss_rpn_loc: 0.369    time: 0.3160  last_time: 0.4529  data_time: 0.0027  last_data_time: 0.0027   lr: 0.00021587  max_mem: 2640M
# [12/03 21:24:30 d2.utils.events]:  eta: 0:00:06  iter: 279  total_loss: 2.461  loss_cls: 1.25  loss_box_reg: 0.8333  loss_rpn_cls: 0.04599  loss_rpn_loc: 0.2892    time: 0.3173  last_time: 0.2939  data_time: 0.0028  last_data_time: 0.0030   lr: 0.00023252  max_mem: 2640M
# [12/03 21:24:37 d2.utils.events]:  eta: 0:00:00  iter: 299  total_loss: 2.404  loss_cls: 1.238  loss_box_reg: 0.8223  loss_rpn_cls: 0.04212  loss_rpn_loc: 0.2713    time: 0.3182  last_time: 0.2359  data_time: 0.0028  last_data_time: 0.0030   lr: 0.00024917  max_mem: 2640M
# [12/03 21:24:37 d2.engine.hooks]: Overall training speed: 298 iterations in 0:01:34 (0.3182 s / it)
# [12/03 21:24:37 d2.engine.hooks]: Total training time: 0:01:45 (0:00:11 on hooks)
# [12/03 21:24:39 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/03 21:24:39 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [12/03 21:24:39 d2.data.common]: Serializing 2560 elements to byte tensors and concatenating them all ...
# [12/03 21:24:39 d2.data.common]: Serialized dataset takes 1.86 MiB
# WARNING [12/03 21:24:39 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %% [markdown]
# # Predict
#
# Now that it is trained, the model can make predictions on images that it has never seen before. Predictions are done by loading in the final weights of the training into the testing model. These can be visualized in the same way that the previous visualizations were made.

# %%
cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-Detection/faster_rcnn_R_50_FPN_3x.yaml"))
#cfg.MODEL.WEIGHTS = '/home/jefferse/aimathsolverproject/output/model_final.pth'
cfg.MODEL.WEIGHTS = "/home/jefferse/aimathsolverproject/output/model_final.pth"
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 54
#cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.7   # set a custom testing threshold

# %%
predictor = DefaultPredictor(cfg)
# Out:
# [12/03 21:25:16 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from /home/jefferse/aimathsolverproject/output/model_final.pth ...

# %%
data = get_formatted_data(batch_path=path_to_testing_batch + "background_images/", json_path=path_to_testing_batch+"JSON/kaggle_data_2.json")

for image in random.sample(data, 3):
    img = cv2.imread(image["file_name"])

    outputs = predictor(img)
    print(outputs)
    print(get_label_mapping())
    v = Visualizer(img[:, :, ::-1],
                   metadata=MetadataCatalog.get("calc_testing"),
                   scale=0.5,
                   instance_mode=ColorMode.IMAGE_BW   # remove the colors of unsegmented pixels. This option is only available for segmentation models
    )
    out = v.draw_instance_predictions(outputs["instances"].to("cpu"))
    plt.imshow(out.get_image()[:, :, ::-1], cmap = 'gray', interpolation = 'bicubic')
    plt.xticks([]), plt.yticks([])  # to hide tick values on X and Y axis
    plt.show()
# Out:
# {'instances': Instances(num_instances=23, image_height=274, image_width=1088, fields=[pred_boxes: Boxes(tensor([[ 314.7049,  124.5098,  357.3281,  186.2475],
#         [ 317.0734,  135.6715,  356.2568,  166.5793],
#         [ 329.0844,  127.5368,  361.6451,  175.4352],
#         [ 194.8575,  194.9070,  240.3581,  237.8567],
#         [ 236.5698,  181.6183,  277.7888,  233.7923],
#         [ 448.3429,  146.2122,  501.9906,  175.4870],
#         [ 318.8203,  127.4406,  343.6411,  174.3980],
#         [1024.7542,  189.3743, 1086.9374,  266.1584],
#         [   6.2653,   15.5140,   57.9070,  149.1822],
#         [ 728.5594,  119.1215,  782.8080,  190.6980],
#         [ 590.7506,  108.4114,  687.2528,  217.8195],
#         [ 842.3857,  167.6002,  894.4599,  213.8825],
#         [ 730.2815,  129.3630,  799.9340,  215.7913],
#         [ 919.2916,  168.7418,  961.6370,  213.2940],
#         [ 295.4219,  104.8370,  367.7599,  176.4659],
#         [ 237.6013,  187.1389,  286.5403,  229.8670],
#         [ 201.2706,  192.2960,  231.8376,  225.9398],
#         [ 821.4736,  148.2293,  896.5179,  217.9265],
#         [ 830.3837,  157.6476,  894.2192,  237.8968],
#         [  74.6429,   86.9578,  247.4277,  144.2685],
#         [ 847.6812,  156.0896,  891.2095,  213.5759],
#         [ 145.8328,   76.3030,  248.5888,  142.5642],
#         [ 603.5475,  102.3653,  675.6960,  211.8356]], device='cuda:0')), scores: tensor([0.1445, 0.1035, 0.0937, 0.0808, 0.0696, 0.0639, 0.0632, 0.0626, 0.0582,
#         0.0571, 0.0570, 0.0552, 0.0547, 0.0543, 0.0543, 0.0529, 0.0527, 0.0525,
#         0.0525, 0.0516, 0.0514, 0.0511, 0.0503], device='cuda:0'), pred_classes: tensor([9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 0, 2, 9, 2, 9, 2, 9, 0, 9, 0, 9, 9, 9],
#        device='cuda:0')])}
# {'\\lim_': 0, 'a': 1, '\\to': 2, '\\frac': 3, '\\pi': 4, '4': 5, 'd': 6, '\\left(': 7, '\\sin': 8, '+': 9, '-': 10, '6': 11, '\\sec': 12, '\\right)': 13, 'w': 14, '/': 15, '5': 16, '\\tan': 17, '2': 18, '3': 19, 'e': 20, 'b': 21, '7': 22, '\\cos': 23, '\\theta': 24, '8': 25, '=': 26, 'x': 27, '9': 28, '1': 29, 'y': 30, 'h': 31, 'k': 32, 'g': 33, '\\csc': 34, '\\infty': 35, '0': 36, '\\sqrt': 37, 'r': 38, '\\ln': 39, 'n': 40, 'u': 41, '\\cot': 42, '\\left|': 43, '\\right|': 44, 'p': 45, 't': 46, 'z': 47, '\\log': 48, 'v': 49, 's': 50, 'c': 51, '\\cdot': 52, '.': 53}
# {'instances': Instances(num_instances=23, image_height=367, image_width=1702, fields=[pred_boxes: Boxes(tensor([[7.5715e+02, 6.1565e+01, 8.1585e+02, 1.3623e+02],
#         [1.1223e+03, 6.9187e+01, 1.1689e+03, 1.2264e+02],
#         [1.5722e+03, 8.9716e+01, 1.6408e+03, 1.7334e+02],
#         [1.0643e+03, 7.6969e+01, 1.1335e+03, 1.6431e+02],
#         [2.5289e+02, 2.9265e+02, 3.1597e+02, 3.2585e+02],
#         [3.3483e+02, 1.0099e+02, 4.4454e+02, 2.4677e+02],
#         [2.1204e+02, 2.9281e+02, 2.6111e+02, 3.5972e+02],
#         [1.5895e+03, 7.7770e+01, 1.6493e+03, 1.5748e+02],
#         [3.3188e+02, 1.5522e+02, 4.4451e+02, 2.5081e+02],
#         [1.1217e+03, 6.9956e+01, 1.1695e+03, 1.2279e+02],
#         [5.8312e+00, 5.3411e+01, 2.1317e+02, 1.9734e+02],
#         [3.2470e+02, 1.4980e+02, 4.6262e+02, 2.7236e+02],
#         [9.3572e+02, 7.6927e+00, 1.0079e+03, 1.2645e+02],
#         [4.9253e+02, 1.8371e+02, 1.7020e+03, 2.1669e+02],
#         [3.5664e+02, 1.5598e+02, 4.4083e+02, 2.5628e+02],
#         [3.1941e+02, 1.4897e+02, 4.6945e+02, 2.7194e+02],
#         [1.4030e+03, 5.4967e+01, 1.4412e+03, 1.2302e+02],
#         [3.3293e+02, 1.4849e+02, 4.4944e+02, 2.5466e+02],
#         [1.0618e+03, 8.6183e+01, 1.1478e+03, 1.7537e+02],
#         [1.0631e+03, 7.8130e+01, 1.1348e+03, 1.6462e+02],
#         [9.3681e+02, 8.2354e+01, 9.8697e+02, 1.2304e+02],
#         [1.1912e+00, 7.9013e+01, 1.9160e+02, 2.3389e+02],
#         [2.1136e+02, 2.9344e+02, 2.6205e+02, 3.6003e+02]], device='cuda:0')), scores: tensor([0.1210, 0.1044, 0.0885, 0.0789, 0.0713, 0.0665, 0.0630, 0.0616, 0.0599,
#         0.0592, 0.0590, 0.0589, 0.0580, 0.0579, 0.0560, 0.0531, 0.0528, 0.0525,
#         0.0524, 0.0521, 0.0521, 0.0504, 0.0503], device='cuda:0'), pred_classes: tensor([ 9,  9,  9,  9,  2,  9,  9,  9,  2,  2,  0,  9,  0,  3,  9,  0, 18, 18,
#          0,  2,  2,  9,  2], device='cuda:0')])}
# {'\\lim_': 0, 'a': 1, '\\to': 2, '\\frac': 3, '\\pi': 4, '4': 5, 'd': 6, '\\left(': 7, '\\sin': 8, '+': 9, '-': 10, '6': 11, '\\sec': 12, '\\right)': 13, 'w': 14, '/': 15, '5': 16, '\\tan': 17, '2': 18, '3': 19, 'e': 20, 'b': 21, '7': 22, '\\cos': 23, '\\theta': 24, '8': 25, '=': 26, 'x': 27, '9': 28, '1': 29, 'y': 30, 'h': 31, 'k': 32, 'g': 33, '\\csc': 34, '\\infty': 35, '0': 36, '\\sqrt': 37, 'r': 38, '\\ln': 39, 'n': 40, 'u': 41, '\\cot': 42, '\\left|': 43, '\\right|': 44, 'p': 45, 't': 46, 'z': 47, '\\log': 48, 'v': 49, 's': 50, 'c': 51, '\\cdot': 52, '.': 53}
# {'instances': Instances(num_instances=17, image_height=364, image_width=816, fields=[pred_boxes: Boxes(tensor([[295.9321, 262.9095, 329.7308, 287.9310],
#         [704.0026, 276.8108, 763.0047, 310.5281],
#         [421.2787, 232.7274, 816.0000, 262.3007],
#         [241.4584, 265.0767, 301.2384, 313.8714],
#         [478.2540, 242.0326, 816.0000, 259.1355],
#         [434.0577, 116.1404, 464.2713, 148.2430],
#         [ 17.4418, 299.2761,  61.4699, 328.4442],
#         [254.7097, 277.3091, 291.8322, 312.6108],
#         [690.9816, 280.2928, 741.8711, 308.7230],
#         [687.2479, 265.3131, 749.7258, 314.7017],
#         [115.9271, 210.4105, 164.9854, 271.9645],
#         [382.7326, 255.8113, 434.3877, 315.8420],
#         [ 57.4977, 283.9757, 101.1933, 316.3880],
#         [590.7357, 271.0532, 637.7142, 316.8367],
#         [240.0589, 281.6111, 278.2924, 312.7165],
#         [340.7086, 268.9301, 373.1864, 290.9644],
#         [428.7900, 118.8538, 486.2697, 144.2013]], device='cuda:0')), scores: tensor([0.0919, 0.0878, 0.0848, 0.0833, 0.0718, 0.0669, 0.0662, 0.0662, 0.0635,
#         0.0633, 0.0631, 0.0599, 0.0575, 0.0568, 0.0563, 0.0562, 0.0518],
#        device='cuda:0'), pred_classes: tensor([9, 9, 3, 9, 3, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9, 9], device='cuda:0')])}
# {'\\lim_': 0, 'a': 1, '\\to': 2, '\\frac': 3, '\\pi': 4, '4': 5, 'd': 6, '\\left(': 7, '\\sin': 8, '+': 9, '-': 10, '6': 11, '\\sec': 12, '\\right)': 13, 'w': 14, '/': 15, '5': 16, '\\tan': 17, '2': 18, '3': 19, 'e': 20, 'b': 21, '7': 22, '\\cos': 23, '\\theta': 24, '8': 25, '=': 26, 'x': 27, '9': 28, '1': 29, 'y': 30, 'h': 31, 'k': 32, 'g': 33, '\\csc': 34, '\\infty': 35, '0': 36, '\\sqrt': 37, 'r': 38, '\\ln': 39, 'n': 40, 'u': 41, '\\cot': 42, '\\left|': 43, '\\right|': 44, 'p': 45, 't': 46, 'z': 47, '\\log': 48, 'v': 49, 's': 50, 'c': 51, '\\cdot': 52, '.': 53}

# %% [markdown]
# # Accuracy

# %%
from detectron2.evaluation import COCOEvaluator, inference_on_dataset
from detectron2.data import build_detection_test_loader
evaluator = COCOEvaluator("calc_testing", ("bbox", "segm"), False, output_dir="./output/")
test_loader = build_detection_test_loader(cfg, "calc_testing")
print(inference_on_dataset(trainer.model, test_loader, evaluator))
# Out:
# [12/03 21:25:28 d2.evaluation.coco_evaluation]: Trying to convert 'calc_testing' to COCO format ...
# WARNING [12/03 21:25:28 d2.data.datasets.coco]: Using previously cached COCO format annotations at './output/calc_testing_coco_format.json'. You need to clear the cache file if your dataset has been modified.
# [12/03 21:25:29 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [12/03 21:25:29 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [12/03 21:25:29 d2.data.common]: Serializing 2560 elements to byte tensors and concatenating them all ...
# [12/03 21:25:29 d2.data.common]: Serialized dataset takes 1.86 MiB
# [12/03 21:25:29 d2.evaluation.evaluator]: Start inference on 2560 batches
# [12/03 21:25:30 d2.evaluation.evaluator]: Inference done 11/2560. Dataloading: 0.0006 s/iter. Inference: 0.0708 s/iter. Eval: 0.0002 s/iter. Total: 0.0716 s/iter. ETA=0:03:02
# [12/03 21:25:35 d2.evaluation.evaluator]: Inference done 82/2560. Dataloading: 0.0009 s/iter. Inference: 0.0703 s/iter. Eval: 0.0002 s/iter. Total: 0.0715 s/iter. ETA=0:02:57
# [12/03 21:25:40 d2.evaluation.evaluator]: Inference done 155/2560. Dataloading: 0.0009 s/iter. Inference: 0.0690 s/iter. Eval: 0.0002 s/iter. Total: 0.0701 s/iter. ETA=0:02:48
# [12/03 21:25:46 d2.evaluation.evaluator]: Inference done 232/2560. Dataloading: 0.0009 s/iter. Inference: 0.0675 s/iter. Eval: 0.0002 s/iter. Total: 0.0687 s/iter. ETA=0:02:39
# [12/03 21:25:51 d2.evaluation.evaluator]: Inference done 305/2560. Dataloading: 0.0009 s/iter. Inference: 0.0676 s/iter. Eval: 0.0002 s/iter. Total: 0.0688 s/iter. ETA=0:02:35
# [12/03 21:25:56 d2.evaluation.evaluator]: Inference done 378/2560. Dataloading: 0.0009 s/iter. Inference: 0.0677 s/iter. Eval: 0.0002 s/iter. Total: 0.0689 s/iter. ETA=0:02:30
# [12/03 21:26:01 d2.evaluation.evaluator]: Inference done 451/2560. Dataloading: 0.0009 s/iter. Inference: 0.0678 s/iter. Eval: 0.0002 s/iter. Total: 0.0690 s/iter. ETA=0:02:25
# [12/03 21:26:06 d2.evaluation.evaluator]: Inference done 522/2560. Dataloading: 0.0009 s/iter. Inference: 0.0681 s/iter. Eval: 0.0002 s/iter. Total: 0.0693 s/iter. ETA=0:02:21
# [12/03 21:26:11 d2.evaluation.evaluator]: Inference done 592/2560. Dataloading: 0.0009 s/iter. Inference: 0.0684 s/iter. Eval: 0.0002 s/iter. Total: 0.0696 s/iter. ETA=0:02:16
# [12/03 21:26:16 d2.evaluation.evaluator]: Inference done 665/2560. Dataloading: 0.0009 s/iter. Inference: 0.0683 s/iter. Eval: 0.0002 s/iter. Total: 0.0695 s/iter. ETA=0:02:11
# [12/03 21:26:21 d2.evaluation.evaluator]: Inference done 739/2560. Dataloading: 0.0009 s/iter. Inference: 0.0682 s/iter. Eval: 0.0002 s/iter. Total: 0.0694 s/iter. ETA=0:02:06
# [12/03 21:26:26 d2.evaluation.evaluator]: Inference done 811/2560. Dataloading: 0.0009 s/iter. Inference: 0.0682 s/iter. Eval: 0.0002 s/iter. Total: 0.0694 s/iter. ETA=0:02:01
# [12/03 21:26:31 d2.evaluation.evaluator]: Inference done 883/2560. Dataloading: 0.0009 s/iter. Inference: 0.0683 s/iter. Eval: 0.0002 s/iter. Total: 0.0695 s/iter. ETA=0:01:56
# [12/03 21:26:36 d2.evaluation.evaluator]: Inference done 954/2560. Dataloading: 0.0009 s/iter. Inference: 0.0684 s/iter. Eval: 0.0002 s/iter. Total: 0.0696 s/iter. ETA=0:01:51
# [12/03 21:26:41 d2.evaluation.evaluator]: Inference done 1027/2560. Dataloading: 0.0009 s/iter. Inference: 0.0684 s/iter. Eval: 0.0002 s/iter. Total: 0.0696 s/iter. ETA=0:01:46
# [12/03 21:26:46 d2.evaluation.evaluator]: Inference done 1097/2560. Dataloading: 0.0009 s/iter. Inference: 0.0685 s/iter. Eval: 0.0002 s/iter. Total: 0.0697 s/iter. ETA=0:01:41
# [12/03 21:26:51 d2.evaluation.evaluator]: Inference done 1168/2560. Dataloading: 0.0009 s/iter. Inference: 0.0686 s/iter. Eval: 0.0002 s/iter. Total: 0.0698 s/iter. ETA=0:01:37
# [12/03 21:26:56 d2.evaluation.evaluator]: Inference done 1238/2560. Dataloading: 0.0009 s/iter. Inference: 0.0687 s/iter. Eval: 0.0002 s/iter. Total: 0.0699 s/iter. ETA=0:01:32
# [12/03 21:27:01 d2.evaluation.evaluator]: Inference done 1309/2560. Dataloading: 0.0009 s/iter. Inference: 0.0688 s/iter. Eval: 0.0002 s/iter. Total: 0.0700 s/iter. ETA=0:01:27
# [12/03 21:27:06 d2.evaluation.evaluator]: Inference done 1369/2560. Dataloading: 0.0009 s/iter. Inference: 0.0694 s/iter. Eval: 0.0002 s/iter. Total: 0.0706 s/iter. ETA=0:01:24
# [12/03 21:27:11 d2.evaluation.evaluator]: Inference done 1438/2560. Dataloading: 0.0009 s/iter. Inference: 0.0695 s/iter. Eval: 0.0002 s/iter. Total: 0.0707 s/iter. ETA=0:01:19
# [12/03 21:27:16 d2.evaluation.evaluator]: Inference done 1504/2560. Dataloading: 0.0009 s/iter. Inference: 0.0697 s/iter. Eval: 0.0002 s/iter. Total: 0.0709 s/iter. ETA=0:01:14
# [12/03 21:27:21 d2.evaluation.evaluator]: Inference done 1572/2560. Dataloading: 0.0009 s/iter. Inference: 0.0699 s/iter. Eval: 0.0002 s/iter. Total: 0.0710 s/iter. ETA=0:01:10
# [12/03 21:27:26 d2.evaluation.evaluator]: Inference done 1642/2560. Dataloading: 0.0009 s/iter. Inference: 0.0699 s/iter. Eval: 0.0002 s/iter. Total: 0.0711 s/iter. ETA=0:01:05
# [12/03 21:27:31 d2.evaluation.evaluator]: Inference done 1710/2560. Dataloading: 0.0009 s/iter. Inference: 0.0700 s/iter. Eval: 0.0002 s/iter. Total: 0.0712 s/iter. ETA=0:01:00
# [12/03 21:27:36 d2.evaluation.evaluator]: Inference done 1779/2560. Dataloading: 0.0009 s/iter. Inference: 0.0701 s/iter. Eval: 0.0002 s/iter. Total: 0.0712 s/iter. ETA=0:00:55
# [12/03 21:27:41 d2.evaluation.evaluator]: Inference done 1852/2560. Dataloading: 0.0009 s/iter. Inference: 0.0700 s/iter. Eval: 0.0002 s/iter. Total: 0.0711 s/iter. ETA=0:00:50
# [12/03 21:27:46 d2.evaluation.evaluator]: Inference done 1923/2560. Dataloading: 0.0009 s/iter. Inference: 0.0700 s/iter. Eval: 0.0002 s/iter. Total: 0.0711 s/iter. ETA=0:00:45
# [12/03 21:27:51 d2.evaluation.evaluator]: Inference done 1995/2560. Dataloading: 0.0009 s/iter. Inference: 0.0699 s/iter. Eval: 0.0002 s/iter. Total: 0.0711 s/iter. ETA=0:00:40
# [12/03 21:27:56 d2.evaluation.evaluator]: Inference done 2067/2560. Dataloading: 0.0009 s/iter. Inference: 0.0699 s/iter. Eval: 0.0002 s/iter. Total: 0.0711 s/iter. ETA=0:00:35
# [12/03 21:28:02 d2.evaluation.evaluator]: Inference done 2139/2560. Dataloading: 0.0009 s/iter. Inference: 0.0699 s/iter. Eval: 0.0002 s/iter. Total: 0.0711 s/iter. ETA=0:00:29
# [12/03 21:28:07 d2.evaluation.evaluator]: Inference done 2210/2560. Dataloading: 0.0009 s/iter. Inference: 0.0699 s/iter. Eval: 0.0002 s/iter. Total: 0.0711 s/iter. ETA=0:00:24
# [12/03 21:28:12 d2.evaluation.evaluator]: Inference done 2281/2560. Dataloading: 0.0009 s/iter. Inference: 0.0699 s/iter. Eval: 0.0002 s/iter. Total: 0.0710 s/iter. ETA=0:00:19
# [12/03 21:28:17 d2.evaluation.evaluator]: Inference done 2355/2560. Dataloading: 0.0009 s/iter. Inference: 0.0698 s/iter. Eval: 0.0002 s/iter. Total: 0.0710 s/iter. ETA=0:00:14
# [12/03 21:28:22 d2.evaluation.evaluator]: Inference done 2429/2560. Dataloading: 0.0009 s/iter. Inference: 0.0697 s/iter. Eval: 0.0002 s/iter. Total: 0.0709 s/iter. ETA=0:00:09
# [12/03 21:28:27 d2.evaluation.evaluator]: Inference done 2500/2560. Dataloading: 0.0009 s/iter. Inference: 0.0697 s/iter. Eval: 0.0002 s/iter. Total: 0.0709 s/iter. ETA=0:00:04
# [12/03 21:28:31 d2.evaluation.evaluator]: Total inference time: 0:03:00.996304 (0.070840 s / iter per device, on 1 devices)
# [12/03 21:28:31 d2.evaluation.evaluator]: Total inference pure compute time: 0:02:57 (0.069643 s / iter per device, on 1 devices)
# [12/03 21:28:31 d2.evaluation.coco_evaluation]: Preparing results for COCO format ...
# [12/03 21:28:31 d2.evaluation.coco_evaluation]: Saving results to ./output/coco_instances_results.json
# [12/03 21:28:31 d2.evaluation.coco_evaluation]: Evaluating predictions with unofficial COCO API...
# Loading and preparing results...
# DONE (t=0.06s)
# creating index...
# index created!
# [12/03 21:28:31 d2.evaluation.fast_eval_api]: Evaluate annotation type *bbox*
# [12/03 21:28:34 d2.evaluation.fast_eval_api]: COCOeval_opt.evaluate() finished in 2.57 seconds.
# [12/03 21:28:34 d2.evaluation.fast_eval_api]: Accumulating evaluation results...
# [12/03 21:28:34 d2.evaluation.fast_eval_api]: COCOeval_opt.accumulate() finished in 0.34 seconds.
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.012
#  Average Precision  (AP) @[ IoU=0.50      | area=   all | maxDets=100 ] = 0.025
#  Average Precision  (AP) @[ IoU=0.75      | area=   all | maxDets=100 ] = 0.009
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.007
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.011
#  Average Precision  (AP) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.009
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=  1 ] = 0.016
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets= 10 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=   all | maxDets=100 ] = 0.026
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= small | maxDets=100 ] = 0.019
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area=medium | maxDets=100 ] = 0.025
#  Average Recall     (AR) @[ IoU=0.50:0.95 | area= large | maxDets=100 ] = 0.025
# [12/03 21:28:34 d2.evaluation.coco_evaluation]: Evaluation results for bbox:
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 1.236 | 2.544  | 0.882  | 0.730 | 1.114 | 0.887 |
# [12/03 21:28:34 d2.evaluation.coco_evaluation]: Per-category bbox AP:
# | category   | AP     | category   | AP    | category   | AP    |
# |:-----------|:-------|:-----------|:------|:-----------|:------|
# | \lim_      | 17.269 | a          | 0.000 | \to        | 8.203 |
# | \frac      | 6.259  | \pi        | 0.000 | 4          | 0.000 |
# | d          | 0.000  | \left(     | 0.000 | \sin       | 0.000 |
# | +          | 34.855 | -          | 0.000 | 6          | 0.000 |
# | \sec       | 0.000  | \right)    | 0.000 | w          | 0.000 |
# | /          | 0.000  | 5          | 0.000 | \tan       | 0.000 |
# | 2          | 0.156  | 3          | 0.000 | e          | 0.000 |
# | b          | 0.000  | 7          | 0.000 | \cos       | 0.000 |
# | \theta     | 0.000  | 8          | 0.000 | =          | 0.000 |
# | x          | 0.000  | 9          | 0.000 | 1          | 0.000 |
# | y          | 0.000  | h          | 0.000 | k          | 0.000 |
# | g          | 0.000  | \csc       | 0.000 | \infty     | 0.000 |
# | 0          | 0.000  | \sqrt      | 0.000 | r          | 0.000 |
# | \ln        | 0.000  | n          | 0.000 | u          | 0.000 |
# | \cot       | 0.000  | \left|     | 0.000 | \right|    | 0.000 |
# | p          | 0.000  | t          | 0.000 | z          | 0.000 |
# | \log       | 0.000  | v          | 0.000 | s          | 0.000 |
# | c          | 0.000  | \cdot      | 0.000 | .          | 0.000 |
# Loading and preparing results...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[17], line 5
#       3 evaluator = COCOEvaluator("calc_testing", ("bbox", "segm"), False, output_dir="./output/")
#       4 test_loader = build_detection_test_loader(cfg, "calc_testing")
# ----> 5 print(inference_on_dataset(trainer.model, test_loader, evaluator))
#
# File ~/detectron2/detectron2/evaluation/evaluator.py:204, in inference_on_dataset(model, data_loader, evaluator)
#     197 total_compute_time_str = str(datetime.timedelta(seconds=int(total_compute_time)))
#     198 logger.info(
#     199     "Total inference pure compute time: {} ({:.6f} s / iter per device, on {} devices)".format(
#     200         total_compute_time_str, total_compute_time / (total - num_warmup), num_devices
#     201     )
#     202 )
# --> 204 results = evaluator.evaluate()
#     205 # An evaluator may return None when not in main process.
#     206 # Replace it by an empty dict instead to make it easier for downstream code to handle
#     207 if results is None:
#
# File ~/detectron2/detectron2/evaluation/coco_evaluation.py:206, in COCOEvaluator.evaluate(self, img_ids)
#     204     self._eval_box_proposals(predictions)
#     205 if "instances" in predictions[0]:
# --> 206     self._eval_predictions(predictions, img_ids=img_ids)
#     207 # Copy so the caller can do whatever with results
#     208 return copy.deepcopy(self._results)
#
# File ~/detectron2/detectron2/evaluation/coco_evaluation.py:266, in COCOEvaluator._eval_predictions(self, predictions, img_ids)
#     263 for task in sorted(tasks):
#     264     assert task in {"bbox", "segm", "keypoints"}, f"Got unknown task: {task}!"
#     265     coco_eval = (
# --> 266         _evaluate_predictions_on_coco(
#     267             self._coco_api,
#     268             coco_results,
#     269             task,
#     270             kpt_oks_sigmas=self._kpt_oks_sigmas,
#     271             cocoeval_fn=COCOeval_opt if self._use_fast_impl else COCOeval,
#     272             img_ids=img_ids,
#     273             max_dets_per_image=self._max_dets_per_image,
#     274         )
#     275         if len(coco_results) > 0
#     276         else None  # cocoapi does not handle empty results very well
#     277     )
#     279     res = self._derive_coco_results(
#     280         coco_eval, task, class_names=self._metadata.get("thing_classes")
#     281     )
#     282     self._results[task] = res
#
# File ~/detectron2/detectron2/evaluation/coco_evaluation.py:590, in _evaluate_predictions_on_coco(coco_gt, coco_results, iou_type, kpt_oks_sigmas, cocoeval_fn, img_ids, max_dets_per_image)
#     587     for c in coco_results:
#     588         c.pop("bbox", None)
# --> 590 coco_dt = coco_gt.loadRes(coco_results)
#     591 coco_eval = cocoeval_fn(coco_gt, coco_dt, iou_type)
#     592 # For COCO, the default max_dets_per_image is [1, 10, 100].
#
# File ~/.local/lib/python3.10/site-packages/pycocotools/coco.py:348, in COCO.loadRes(self, resFile)
#     345 res.dataset['categories'] = copy.deepcopy(self.dataset['categories'])
#     346 for id, ann in enumerate(anns):
#     347     # now only support compressed RLE format as segmentation results
# --> 348     ann['area'] = maskUtils.area(ann['segmentation'])
#     349     if not 'bbox' in ann:
#     350         ann['bbox'] = maskUtils.toBbox(ann['segmentation'])
#
# File ~/.local/lib/python3.10/site-packages/pycocotools/mask.py:95, in area(rleObjs)
#      93 def area(rleObjs):
#      94     if type(rleObjs) == list:
# ---> 95         return _mask.area(rleObjs)
#      96     else:
#      97         return _mask.area([rleObjs])[0]
#
# File pycocotools/_mask.pyx:160, in pycocotools._mask.area()
#
# File pycocotools/_mask.pyx:127, in pycocotools._mask._frString()
#
# TypeError: list indices must be integers or slices, not str

# %% [markdown]
# # Accuracy Metrics
#
# |  AP   |  AP50  |  AP75  |  APs  |  APm  |  APl  |
# |:-----:|:------:|:------:|:-----:|:-----:|:-----:|
# | 1.236 | 2.544  | 0.882  | 0.730 | 1.114 | 0.887 |
#
# | category   | AP     | category   | AP    | category   | AP    |
# |:-----------|:-------|:-----------|:------|:-----------|:------|
# | \lim_      | 17.269 | a          | 0.000 | \to        | 8.203 |
# | \frac      | 6.259  | \pi        | 0.000 | 4          | 0.000 |
# | d          | 0.000  | \left(     | 0.000 | \sin       | 0.000 |
# | +          | 34.855 | -          | 0.000 | 6          | 0.000 |
# | \sec       | 0.000  | \right)    | 0.000 | w          | 0.000 |
# | /          | 0.000  | 5          | 0.000 | \tan       | 0.000 |
# | 2          | 0.156  | 3          | 0.000 | e          | 0.000 |
# | b          | 0.000  | 7          | 0.000 | \cos       | 0.000 |
# | \theta     | 0.000  | 8          | 0.000 | =          | 0.000 |
# | x          | 0.000  | 9          | 0.000 | 1          | 0.000 |
# | y          | 0.000  | h          | 0.000 | k          | 0.000 |
# | g          | 0.000  | \csc       | 0.000 | \infty     | 0.000 |
# | 0          | 0.000  | \sqrt      | 0.000 | r          | 0.000 |
# | \ln        | 0.000  | n          | 0.000 | u          | 0.000 |
# | \cot       | 0.000  | \left|     | 0.000 | \right|    | 0.000 |
# | p          | 0.000  | t          | 0.000 | z          | 0.000 |
# | \log       | 0.000  | v          | 0.000 | s          | 0.000 |
# | c          | 0.000  | \cdot      | 0.000 | .          | 0.000 |
